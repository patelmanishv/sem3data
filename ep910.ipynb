# %% [markdown]
# ## MATPLOTLIB EXERCISE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. **Task 1: Line Plot with Legends**
#    - Create a subplot of line plot in subplot 1.
#    - Define two sets of data points -
#       - Data for line 1:
#          - `x1 = [10, 20, 30]`
#          - `y1 = [20, 40, 10]`
#    - Data for line 2:
#          - `x2 = [10, 20, 30]`
#          - `y2 = [40, 10, 30]`
#    - Plot these data points
#    - Add a legend
#
# 2. **Task 2: Scatter Plot**
#    - Create a subplot of scatter plot in subplot 2`.
#    - Define three sets of weight and height data points.
#    - Data for weight and height:
#      - `weight1 = [67, 57.2, 59.6, 59.64, 55.8, 61.2, 60.45, 61, 56.23, 56]`
#      - `height1 = [101.7, 197.6, 98.3, 125.1, 113.7, 157.7, 136, 148.9, 125.3, 114.9]`
#      - `weight2 = [61.9, 64, 62.1, 64.2, 62.3, 65.4, 62.4, 61.4, 62.5, 63.6]`
#      - `height2 = [152.8, 155.3, 135.1, 125.2, 151.3, 135, 182.2, 195.9, 165.1, 125.1]`
#      - `weight3 = [68.2, 67.2, 68.4, 68.7, 71, 71.3, 70.8, 70, 71.1, 71.7]`
#      - `height3 = [165.8, 170.9, 192.8, 135.4, 161.4, 136.1, 167.1, 235.1, 181.1, 177.3]`
#
#    - Combine height and weight data points.
#    - Plot the combined data points as a scatter plot using `plt.scatter()`.
#
# 3. **Task 3: Vertical Bar Plot**
#    - Create a subplot of bar plot in subplot 4`.
#    - Define data for categories (`x`) and their corresponding values (`popularity`).
#     - Data for categories and popularity:
#          - `x = ['A', 'B', 'C', 'D', 'E', 'F']`
#          - `popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]`
#    - Plot a vertical bar plot using `plt.bar()`.
#
# 4. **Task 4: Pie Chart**
#    - Create a subplot of piechart in subplot 4.
#    - Define data for programming languages (`languages`) and their corresponding popularity values (`popuratity`).
#       - Data for programming languages and their popularity:
#      - `languages = 'L', 'M', 'N', 'O', 'P', 'Q'`
#      - `popuratity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]`
#    - Specify colors for each slice of the pie chart.
#    - Define the explode parameter to emphasize one slice.
#    - Plot the pie chart using `plt.pie()`, with labels, colors, autopct for percentage display, shadow, startangle, and radius.

# %% [markdown]
# ## OUTPUT

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt

#Task 1
plt.subplot(2, 1, 1)
x1 = [10,20,30]
y1 = [20,40,10]
# line 2 points
x2 = [10,20,30]
y2 = [40,10,30]

# Display the figure.
plt.plot(x1,y1, color='blue', linewidth = 3,  label = 'line1-width-3')
plt.plot(x2,y2, color='red', linewidth = 5,  label = 'line2-width-5')
# show a legend on the plot
plt.legend()

#Task 2
plt.subplot(2, 3, 4)
import matplotlib.pyplot as plt
import numpy as np
weight1=[67,57.2,59.6,59.64,55.8,61.2,60.45,61,56.23,56]
height1=[101.7,197.6,98.3,125.1,113.7,157.7,136,148.9,125.3,114.9]
weight2=[61.9,64,62.1,64.2,62.3,65.4,62.4,61.4,62.5,63.6]
height2=[152.8,155.3,135.1,125.2,151.3,135,182.2,195.9,165.1,125.1]
weight3=[68.2,67.2,68.4,68.7,71,71.3,70.8,70,71.1,71.7]
height3=[165.8,170.9,192.8,135.4,161.4,136.1,167.1,235.1,181.1,177.3]
weight=np.concatenate((weight1,weight2,weight3))
height=np.concatenate((height1,height2,height3))
plt.scatter(weight, height, marker='*', color=['blue'])
plt.xlabel('weight', fontsize=16)
plt.ylabel('height', fontsize=16)

#Task 3
plt.subplot(2, 3, 5)
import matplotlib.pyplot as plt
x = ['A', 'B', 'C', 'D', 'E', 'F']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

plt.bar(x, popularity, color=['red', 'black', 'green', 'blue', 'yellow', 'cyan'])

#Task 4
plt.subplot(2, 3, 6)
import matplotlib.pyplot as plt
# Plot data
languages = 'L', 'M', 'N', 'O', 'P', 'Q'
popuratity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
colors = ['red', 'gold', 'yellowgreen', 'blue', 'lightcoral', 'lightskyblue']
# explode 1st slice
explode = (0.1, 0, 0, 0, 0, 0)  
# Plot
plt.pie(popuratity, explode=explode, labels=languages, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140,radius=1.2)

plt.show()
